# %%
import os
os.chdir('/srv/ccrc/RegClim/z5239661/data53/sdmbc/example')
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /srv/ccrc/RegClim/z5239661/data53/sdmbc/example

# %%
from sdmbc import BiasCorrection
from user_input import *

# %%
# Create an instance of the BiasCorrection class
bias_correction = BiasCorrection(bc_path, level, startyear, 
                                 endyear, no_of_variables, 
                                 time_scale, no_of_iterations, 
                                 missing_value, lon_range, 
                                 lat_range, moving_window, 
                                 correction_model, sub_daily_correction,
                                 lower_limit, upper_limit)
print(bc_path,correction,draw_figure,reformat_to_original)
# Out:
# /srv/ccrc/RegClim/z5239661/data53/sdmbc/example/ 1 1 0

# %%
bias_correction.perform_bias_correction(correction,
                                        draw_figure,
                                        reformat_to_original)
# Out:
# Update biascorrection_input.dat file
# Start bias correction
#   User-defined information is provided
#   -----------------------------------------------------
#   Start year of observed data                 :        1982
#   Number of years of observed data            :          31
#   Start year of raw data                      :        1982
#   Number of years of raw data                 :          31
#   -----------------------------------------------------
#   Information on other parameters
#   -----------------------------------------------------
#   Width of moving window                  :          15
#   Number of iterations                    :           3
#   Number of variables considered          :           4
#   Time nesting and type of bias correction:
#       1-included         0-excluded
#   -----------------------------------------------------
#  Time       MEAN  SD/  LAG1 Auto LAG0 CROSS  LAG1 CROSS
#                  Dist.
# ...
